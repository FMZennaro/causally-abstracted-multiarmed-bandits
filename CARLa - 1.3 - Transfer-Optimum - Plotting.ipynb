# %%
import os
os.chdir(os.path.abspath(os.path.pardir))

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
import numpy as np
import matplotlib.pyplot as plt
import joblib

# %%
avgregrets1 = joblib.load('proj CARLa 3_0/results/simul_1_1_avgregrets.pkl')
avgregrets2 = joblib.load('proj CARLa 3_0/results/simul_1_2_avgregrets.pkl')

# %%
import matplotlib
font = {'family' : 'sans-serif',
        'weight' : 'normal',
        'size'   : 18}

plt.rc('font', **font)

# %%
n_steps = [10, 25, 50, 100, 250, 500]
plt.plot(n_steps,avgregrets1[0],label='base:ucb',linestyle='--',marker='x',color='b')
plt.plot(n_steps,avgregrets1[1],label='abs:TO',color='b')

plt.plot(n_steps,avgregrets2[0],label='base:ucb',linestyle='--',marker='x',color='g')
plt.plot(n_steps,avgregrets2[1],label='abs:TO',color='g')


plt.xlabel('T')
plt.ylabel('$\\dot{\\rho}$')
# Out:
# Text(0, 0.5, '$\\dot{\\rho}$')
