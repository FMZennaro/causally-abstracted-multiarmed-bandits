# %%
import os
os.chdir(os.path.abspath(os.path.pardir))

# %%
import numpy as np
import matplotlib.pyplot as plt
import joblib

# %%
avgregrets1 = joblib.load('proj CARLa 3_0/results/simul_3_1_avgcumregrets.pkl')
avgregrets2 = joblib.load('proj CARLa 3_0/results/simul_3_2_avgcumregrets.pkl')

# %%
import matplotlib
font = {'family' : 'sans-serif',
        'weight' : 'normal',
        'size'   : 18}

plt.rc('font', **font)

# %%
n_steps = range(len(avgregrets1[0]))
plt.plot(n_steps,avgregrets1[0],label='abs:ucb',linestyle='--',color='b')
plt.plot(n_steps,avgregrets1[1],label='abs:TExp',color='b')

plt.plot(n_steps,avgregrets2[0],label='abs:ucb',linestyle='--',color='g')
plt.plot(n_steps,avgregrets2[1],label='abs:TExp',color='g')


plt.xlabel('T')
plt.ylabel('${\\rho}$')
# Out:
# Text(0, 0.5, '${\\rho}$')
